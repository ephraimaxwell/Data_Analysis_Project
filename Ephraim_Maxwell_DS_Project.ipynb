# %%
#imported the required libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading /reading  the csv file
data = pd.read_csv("kc_house_data.csv")
data
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors waterfront  view  ...          grade sqft_above  \
# ...

# %%
#Checking the top 5 rows
data.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors waterfront  view  ...          grade sqft_above  \
# 0      5650     1.0        NaN  NONE  ...      7 Average       1180
# 1      7242     2.0         NO  NONE  ...      7 Average       2170
# 2     10000     1.0         NO  NONE  ...  6 Low Average        770
# 3      5000     1.0         NO  NONE  ...      7 Average       1050
# 4      8080     1.0         NO  NONE  ...         8 Good       1680
#
#    sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
#Checking the last 5 rows
data.tail()
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors waterfront  view  ...      grade sqft_above  \
# 21592      1131     3.0         NO  NONE  ...     8 Good       1530
# 21593      5813     2.0         NO  NONE  ...     8 Good       2310
# 21594      1350     2.0         NO  NONE  ...  7 Average       1020
# 21595      2388     2.0        NaN  NONE  ...     8 Good       1600
# 21596      1076     2.0         NO  NONE  ...  7 Average       1020
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
#Checking the dataset shape
data.shape
# Out:
# (21597, 21)

# %%
#Checking dataset information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  object
#  9   view           21534 non-null  object
#  10  condition      21597 non-null  object
#  11  grade          21597 non-null  object
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %%
#Concise summary statistics 
data.describe().T
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# yr_built       21597.0  1.971000e+03  2.937523e+01  1.900000e+03
# yr_renovated   17755.0  8.363678e+01  3.999464e+02  0.000000e+00
# zipcode        21597.0  9.807795e+04  5.351307e+01  9.800100e+04
# lat            21597.0  4.756009e+01  1.385518e-01  4.715590e+01
# long           21597.0 -1.222140e+02  1.407235e-01 -1.225190e+02
# ...

# %%
#Describe categoral features
data.describe(include = "O")
# Out:
#              date waterfront   view condition      grade sqft_basement
# count       21597      19221  21534     21597      21597         21597
# unique        372          2      5         5         11           304
# top     6/23/2014         NO   NONE   Average  7 Average           0.0
# freq          142      19075  19422     14020       8974         12826

# %%
#Creating a dataframe copy to be used in data cleaning using copy() method
data1 = data.copy(deep= True)
data1
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors waterfront  view  ...          grade sqft_above  \
# ...

# %% [markdown]
# Data Cleaning of the dataset

# %%
#checking unique value in one column
data1['condition'].unique()
# Out:
# array(['Average', 'Very Good', 'Good', 'Poor', 'Fair'], dtype=object)

# %%
#Checking unique values in all the columns 
for i in data1:
    column_val = data1[i].unique()
    print(f"column name: {i}, '/n' : {column_val} , /n")
# Out:
# column name: id, '/n' : [7129300520 6414100192 5631500400 ... 1523300141  291310100 1523300157] , /n
# column name: date, '/n' : ['10/13/2014' '12/9/2014' '2/25/2015' '2/18/2015' '5/12/2014' '6/27/2014'
#  '1/15/2015' '4/15/2015' '3/12/2015' '4/3/2015' '5/27/2014' '5/28/2014'
#  '10/7/2014' '1/24/2015' '7/31/2014' '5/29/2014' '12/5/2014' '4/24/2015'
#  '5/14/2014' '8/26/2014' '7/3/2014' '5/16/2014' '11/20/2014' '11/3/2014'
#  '6/26/2014' '12/1/2014' '6/24/2014' '3/2/2015' '11/10/2014' '12/3/2014'
#  '6/13/2014' '12/30/2014' '2/13/2015' '6/20/2014' '7/15/2014' '8/11/2014'
#  '7/7/2014' '10/28/2014' '7/29/2014' '7/18/2014' '3/25/2015' '7/16/2014'
#  '4/28/2015' '3/11/2015' '9/16/2014' '2/17/2015' '12/31/2014' '2/5/2015'
#  '3/3/2015' '8/19/2014' '4/7/2015' '8/27/2014' '2/23/2015' '12/10/2014'
#  '8/28/2014' '10/21/2014' '12/7/2014' '6/3/2014' '9/9/2014' '10/9/2014'
#  '8/25/2014' '6/12/2014' '9/12/2014' '1/5/2015' '6/10/2014' '7/10/2014'
# ...

# %%
#Checking the colunms use columns attribute
data1.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
#Changing the columns using .capitalize() for uniformity
data1.columns = data1.columns.str.capitalize()
data1.columns
# Out:
# Index(['Id', 'Date', 'Price', 'Bedrooms', 'Bathrooms', 'Sqft_living',
#        'Sqft_lot', 'Floors', 'Waterfront', 'View', 'Condition', 'Grade',
#        'Sqft_above', 'Sqft_basement', 'Yr_built', 'Yr_renovated', 'Zipcode',
#        'Lat', 'Long', 'Sqft_living15', 'Sqft_lot15'],
#       dtype='object')

# %%
#Removing any whitespaces if any by using .replace()
data1.columns = data1.columns.str.replace(" ", " ")
data1.columns
# Out:
# Index(['Id', 'Date', 'Price', 'Bedrooms', 'Bathrooms', 'Sqft_living',
#        'Sqft_lot', 'Floors', 'Waterfront', 'View', 'Condition', 'Grade',
#        'Sqft_above', 'Sqft_basement', 'Yr_built', 'Yr_renovated', 'Zipcode',
#        'Lat', 'Long', 'Sqft_living15', 'Sqft_lot15'],
#       dtype='object')

# %%
#Checking for mising values by using isnull()
data1.isnull()
# Out:
#           Id   Date  Price  Bedrooms  Bathrooms  Sqft_living  Sqft_lot  \
# 0      False  False  False     False      False        False     False
# 1      False  False  False     False      False        False     False
# 2      False  False  False     False      False        False     False
# 3      False  False  False     False      False        False     False
# 4      False  False  False     False      False        False     False
# ...      ...    ...    ...       ...        ...          ...       ...
# 21592  False  False  False     False      False        False     False
# 21593  False  False  False     False      False        False     False
# 21594  False  False  False     False      False        False     False
# 21595  False  False  False     False      False        False     False
# 21596  False  False  False     False      False        False     False
#
#        Floors  Waterfront   View  ...  Grade  Sqft_above  Sqft_basement  \
# ...

# %%
#Checking the number of missing values 
data1.isnull().sum()
# Out:
# Id                  0
# Date                0
# Price               0
# Bedrooms            0
# Bathrooms           0
# Sqft_living         0
# Sqft_lot            0
# Floors              0
# Waterfront       2376
# View               63
# Condition           0
# Grade               0
# Sqft_above          0
# Sqft_basement       0
# Yr_built            0
# Yr_renovated     3842
# Zipcode             0
# Lat                 0
# Long                0
# Sqft_living15       0
# Sqft_lot15          0
# dtype: int64

# %%
#The code below was used to drop every row that had a null value
data1.dropna().isnull().sum()
# Out:
# Id               0
# Date             0
# Price            0
# Bedrooms         0
# Bathrooms        0
# Sqft_living      0
# Sqft_lot         0
# Floors           0
# Waterfront       0
# View             0
# Condition        0
# Grade            0
# Sqft_above       0
# Sqft_basement    0
# Yr_built         0
# Yr_renovated     0
# Zipcode          0
# Lat              0
# Long             0
# Sqft_living15    0
# Sqft_lot15       0
# dtype: int64

# %%
#Checking for duplicates using .duplicated()
data1.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21592    False
# 21593    False
# 21594    False
# 21595    False
# 21596    False
# Length: 21597, dtype: bool

# %%
#Checking for total number of duplicates 
data1.duplicated().sum()
# Out:
# 0

# %%
#Checking for an outlier
sns.boxplot(data1)
# Out:
# <Axes: >

# %% [markdown]
# Data Analysis of the dataset

# %%
#Creating a new column in the dataset that shows the difference between year of renovation and year built called as Yr_dif
data1['Yr_dif'] = data1['Yr_renovated'] - data1['Yr_built']
data1
# Out:
#                Id        Date     Price  Bedrooms  Bathrooms  Sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        Sqft_lot  Floors Waterfront  View  ... Sqft_above Sqft_basement  \
# ...

# %%
#Separating the required columns from the rest of the dataset
renovated = data1.iloc[0:,[ 2, 3, 7, 8, 9, 10, 12, 14, 15, 21]]
renovated
# Out:
#           Price  Bedrooms  Floors Waterfront  View  Condition  Sqft_above  \
# 0      221900.0         3     1.0        NaN  NONE    Average        1180
# 1      538000.0         3     2.0         NO  NONE    Average        2170
# 2      180000.0         2     1.0         NO  NONE    Average         770
# 3      604000.0         4     1.0         NO  NONE  Very Good        1050
# 4      510000.0         3     1.0         NO  NONE    Average        1680
# ...         ...       ...     ...        ...   ...        ...         ...
# 21592  360000.0         3     3.0         NO  NONE    Average        1530
# 21593  400000.0         4     2.0         NO  NONE    Average        2310
# 21594  402101.0         2     2.0         NO  NONE    Average        1020
# 21595  400000.0         3     2.0        NaN  NONE    Average        1600
# 21596  325000.0         2     2.0         NO  NONE    Average        1020
#
#        Yr_built  Yr_renovated  Yr_dif
# 0          1955           0.0 -1955.0
# ...

# %%
#Finding the mode  of the Sqft_above which will be used in the analysis
renovated['Sqft_above'].mode()
# Out:
# 0    1300
# Name: Sqft_above, dtype: int64

# %%
#The variable renovate shows the house that had been renovated with their respective years
renovate = renovated[(renovated['Yr_renovated'] > 1600)]
renovate
# Out:
#            Price  Bedrooms  Floors Waterfront  View Condition  Sqft_above  \
# 1       538000.0         3     2.0         NO  NONE   Average        2170
# 35      696000.0         3     1.5         NO  NONE   Average        1510
# 95      905000.0         4     1.0         NO  NONE   Average        2390
# 103    1090000.0         3     2.0         NO  NONE   Average        2920
# 125    1450000.0         4     1.5         NO  NONE   Average        1980
# ...          ...       ...     ...        ...   ...       ...         ...
# 19602   451000.0         2     1.0         NO  NONE   Average         900
# 20041   434900.0         3     2.0         NO  NONE   Average        1520
# 20428   500012.0         4     1.0         NO  NONE   Average        1230
# 20431   356999.0         3     2.0        NaN  NONE   Average        1010
# 20946   110000.0         2     1.0         NO  NONE   Average         828
#
#        Yr_built  Yr_renovated  Yr_dif
# 1          1951        1991.0    40.0
# ...

# %%
#The variable non_renovate shows the hoouses that hasn't been renovated hence their year of renovation hasn't been indicated  
non_renovate = renovated[(renovated['Yr_renovated'] < 1600)]
non_renovate
# Out:
#            Price  Bedrooms  Floors Waterfront  View  Condition  Sqft_above  \
# 0       221900.0         3     1.0        NaN  NONE    Average        1180
# 3       604000.0         4     1.0         NO  NONE  Very Good        1050
# 4       510000.0         3     1.0         NO  NONE    Average        1680
# 5      1230000.0         4     1.0         NO  NONE    Average        3890
# 6       257500.0         3     2.0         NO  NONE    Average        1715
# ...          ...       ...     ...        ...   ...        ...         ...
# 21592   360000.0         3     3.0         NO  NONE    Average        1530
# 21593   400000.0         4     2.0         NO  NONE    Average        2310
# 21594   402101.0         2     2.0         NO  NONE    Average        1020
# 21595   400000.0         3     2.0        NaN  NONE    Average        1600
# 21596   325000.0         2     2.0         NO  NONE    Average        1020
#
#        Yr_built  Yr_renovated  Yr_dif
# ...

# %%
#Show the mode of the price, year of renovation and squarefoot above for renovated houses 
renovate[['Yr_renovated', 'Sqft_above', 'Price']].agg(['mode'])
# Out:
#   Yr_renovated Sqft_above     Price
#           mode       mode      mode
# 0       2014.0       1560  550000.0

# %%
#The variable above shows all the values that has '1300' under the column of Sqft_above from the info obtained in renovate
above = renovate[(renovate['Sqft_above'] == 1300)]
above
# Out:
#           Price  Bedrooms  Floors Waterfront  View Condition  Sqft_above  \
# 379    435000.0         3     1.5         NO  NONE   Average        1300
# 2683   312000.0         4     1.0         NO  NONE   Average        1300
# 15294  492000.0         2     1.0         NO  NONE      Good        1300
# 16832  260000.0         3     1.0         NO  NONE   Average        1300
#
#        Yr_built  Yr_renovated  Yr_dif
# 379        1904        2014.0   110.0
# 2683       1950        2013.0    63.0
# 15294      1945        1986.0    41.0
# 16832      1962        2007.0    45.0

# %%
#The variable price is used to portray the info of price from the variable renovate 
Price = renovate.iloc[0:, :1]
Price
# Out:
#            Price
# 1       538000.0
# 35      696000.0
# 95      905000.0
# 103    1090000.0
# 125    1450000.0
# ...          ...
# 19602   451000.0
# 20041   434900.0
# 20428   500012.0
# 20431   356999.0
# 20946   110000.0
#
# [744 rows x 1 columns]

# %%
##The variable bedrooms is used to portray the info of bedrooms from the variable renovate 
Bedrooms = renovate.iloc[0:, 1:2]
Bedrooms
# Out:
#        Bedrooms
# 1             3
# 35            3
# 95            4
# 103           3
# 125           4
# ...         ...
# 19602         2
# 20041         3
# 20428         4
# 20431         3
# 20946         2
#
# [744 rows x 1 columns]

# %%
#The variable no_beds has been used to portray the info the years of renovation for the houses that has been indicated 
no_beds = above[(above['Yr_renovated'] > 1600)]
no_beds
# Out:
#           Price  Bedrooms  Floors Waterfront  View Condition  Sqft_above  \
# 379    435000.0         3     1.5         NO  NONE   Average        1300
# 2683   312000.0         4     1.0         NO  NONE   Average        1300
# 15294  492000.0         2     1.0         NO  NONE      Good        1300
# 16832  260000.0         3     1.0         NO  NONE   Average        1300
#
#        Yr_built  Yr_renovated  Yr_dif
# 379        1904        2014.0   110.0
# 2683       1950        2013.0    63.0
# 15294      1945        1986.0    41.0
# 16832      1962        2007.0    45.0

# %%
#The variable bed3 has been used to show all rows that has 3 bedrooms in order to get the mean in the next cell
bed3 = no_beds[(no_beds['Bedrooms'] == 3)]
bed3
# Out:
#           Price  Bedrooms  Floors Waterfront  View Condition  Sqft_above  \
# 379    435000.0         3     1.5         NO  NONE   Average        1300
# 16832  260000.0         3     1.0         NO  NONE   Average        1300
#
#        Yr_built  Yr_renovated  Yr_dif
# 379        1904        2014.0   110.0
# 16832      1962        2007.0    45.0

# %%
#The code below has been used to get the mean of the prices for 3 bedrooms houses
price_3 = round(bed3['Price'].mean(),2)
price_3
# Out:
# 347500.0

# %%
#The variable bed4 has been used to show all rows that has 4 bedrooms in order to get the mean in the next cell
bed4 = no_beds[(no_beds['Bedrooms'] == 4)]
bed4
# Out:
#          Price  Bedrooms  Floors Waterfront  View Condition  Sqft_above  \
# 2683  312000.0         4     1.0         NO  NONE   Average        1300
#
#       Yr_built  Yr_renovated  Yr_dif
# 2683      1950        2013.0    63.0

# %%
#The code below has been used to get the mean of the prices for 4 bedrooms houses
round(bed4['Price'].mean(),2)
# Out:
# 312000.0

# %%
#The variable bed1 has been used to show all rows that has 1 bedrooms in order to get the mean in the next cell
bed1 = no_beds[(no_beds['Bedrooms'] == 1)]
bed1
# Out:
# Empty DataFrame
# Columns: [Price, Bedrooms, Floors, Waterfront, View, Condition, Sqft_above, Yr_built, Yr_renovated, Yr_dif]
# Index: []

# %%
#The code below has been used to get the mean of the prices for 1 bedrooms houses
round(bed1['Price'].mean(),2)
# Out:
# nan

# %%
#The variable bed2 has been used to show all rows that has 2 bedrooms in order to get the mean in the next cell
bed2 = no_beds[(no_beds['Bedrooms'] == 2)]
bed2
# Out:
#           Price  Bedrooms  Floors Waterfront  View Condition  Sqft_above  \
# 15294  492000.0         2     1.0         NO  NONE      Good        1300
#
#        Yr_built  Yr_renovated  Yr_dif
# 15294      1945        1986.0    41.0

# %%
#The code below has been used to get the mean of the prices for 2 bedrooms houses
round(bed2['Price'].mean(),2)
# Out:
# 492000.0

# %%
#The code below has been used to get the mean for price, year of renovated and squarefoot above for non_renovated houses
non_renovate[['Yr_renovated', 'Sqft_above', 'Price']].agg(['mode'])
# Out:
#   Yr_renovated Sqft_above     Price
#           mode       mode      mode
# 0          0.0       1200  350000.0
# 1          NaN       1300       NaN

# %%
#The variable below holds the extracted data from the variable non_renovate which is all the houses that hasn't been renovated
below = non_renovate[(non_renovate['Yr_renovated'] == 0)]
below
# Out:
#            Price  Bedrooms  Floors Waterfront  View  Condition  Sqft_above  \
# 0       221900.0         3     1.0        NaN  NONE    Average        1180
# 3       604000.0         4     1.0         NO  NONE  Very Good        1050
# 4       510000.0         3     1.0         NO  NONE    Average        1680
# 5      1230000.0         4     1.0         NO  NONE    Average        3890
# 6       257500.0         3     2.0         NO  NONE    Average        1715
# ...          ...       ...     ...        ...   ...        ...         ...
# 21592   360000.0         3     3.0         NO  NONE    Average        1530
# 21593   400000.0         4     2.0         NO  NONE    Average        2310
# 21594   402101.0         2     2.0         NO  NONE    Average        1020
# 21595   400000.0         3     2.0        NaN  NONE    Average        1600
# 21596   325000.0         2     2.0         NO  NONE    Average        1020
#
#        Yr_built  Yr_renovated  Yr_dif
# ...

# %%
#The variable above shows all the values that has '1300' under the column of Sqft_above from the info obtained in the variable below
non_beds = below[(below['Sqft_above'] == 1300)]
non_beds
# Out:
#           Price  Bedrooms  Floors Waterfront  View  Condition  Sqft_above  \
# 243    225000.0         3     1.0         NO  NONE       Good        1300
# 342    425000.0         3     1.0         NO  NONE    Average        1300
# 352    315000.0         3     1.0         NO  NONE       Good        1300
# 448    475000.0         5     1.0         NO  NONE    Average        1300
# 492    232000.0         3     1.0         NO  NONE  Very Good        1300
# ...         ...       ...     ...        ...   ...        ...         ...
# 20104  439990.0         3     2.0         NO  NONE    Average        1300
# 20530  515000.0         3     3.0        NaN  NONE    Average        1300
# 20655  310000.0         3     2.0        NaN  NONE    Average        1300
# 20990  415000.0         3     2.0        NaN  NONE    Average        1300
# 21208  610000.0         3     3.0         NO  NONE    Average        1300
#
#        Yr_built  Yr_renovated  Yr_dif
# 243        1954           0.0 -1954.0
# ...

# %%
#The variable non_bed1 has been used to show all rows that has 1 bedrooms in order to get the mean in the next cell
non_bed1 = non_beds[(non_beds['Bedrooms'] == 1)]
non_bed1
# Out:
# Empty DataFrame
# Columns: [Price, Bedrooms, Floors, Waterfront, View, Condition, Sqft_above, Yr_built, Yr_renovated, Yr_dif]
# Index: []

# %%
#The code below has been used to get the mean of the prices for 1 bedrooms houses
round(non_bed1['Price'].mean(),2)
# Out:
# nan

# %%
#The variable non_bed2 has been used to show all rows that has 1 bedrooms in order to get the mean in the next cell
non_bed2 = non_beds[(non_beds['Bedrooms'] == 2)]
non_bed2
# Out:
#           Price  Bedrooms  Floors Waterfront       View  Condition  \
# 1790   225000.0         2     1.5         NO       NONE       Good
# 2374   175000.0         2     1.0         NO       NONE  Very Good
# 3570   230000.0         2     1.0         NO       NONE    Average
# 4224   509500.0         2     2.0         NO       NONE    Average
# 6133   425000.0         2     1.0        NaN       NONE       Good
# 6201   337500.0         2     1.0         NO       NONE    Average
# 6326   430000.0         2     1.0         NO    AVERAGE    Average
# 7115   750000.0         2     1.0         NO    AVERAGE    Average
# 7869   439888.0         2     1.0         NO       NONE    Average
# 8996   431000.0         2     1.5         NO       NONE       Good
# 9584   700000.0         2     1.0         NO       NONE       Good
# 10041  665000.0         2     1.0         NO       NONE  Very Good
# 10043  620000.0         2     1.5         NO       NONE    Average
# ...

# %%
#The code below has been used to get the mean of the prices for 2 bedrooms houses
round(non_bed2['Price'].mean(),2)
# Out:
# 444792.29

# %%
#The variable non_bed3 has been used to show all rows that has 1 bedrooms in order to get the mean in the next cell
non_bed3 = non_beds[(non_beds['Bedrooms'] == 3)]
non_bed3
# Out:
#           Price  Bedrooms  Floors Waterfront  View  Condition  Sqft_above  \
# 243    225000.0         3     1.0         NO  NONE       Good        1300
# 342    425000.0         3     1.0         NO  NONE    Average        1300
# 352    315000.0         3     1.0         NO  NONE       Good        1300
# 492    232000.0         3     1.0         NO  NONE  Very Good        1300
# 554    396000.0         3     1.0         NO  NONE  Very Good        1300
# ...         ...       ...     ...        ...   ...        ...         ...
# 20104  439990.0         3     2.0         NO  NONE    Average        1300
# 20530  515000.0         3     3.0        NaN  NONE    Average        1300
# 20655  310000.0         3     2.0        NaN  NONE    Average        1300
# 20990  415000.0         3     2.0        NaN  NONE    Average        1300
# 21208  610000.0         3     3.0         NO  NONE    Average        1300
#
#        Yr_built  Yr_renovated  Yr_dif
# 243        1954           0.0 -1954.0
# ...

# %%
#The code below has been used to get the mean of the prices for 3 bedrooms houses
price3 = round(non_bed3['Price'].mean(),2)
price3
# Out:
# 399053.65

# %%
#The variable non_bed4 has been used to show all rows that has 1 bedrooms in order to get the mean in the next cell
non_bed4 = non_beds[(non_beds['Bedrooms'] == 4)]
non_bed4
# Out:
#            Price  Bedrooms  Floors Waterfront     View  Condition  Sqft_above  \
# 827     175000.0         4     1.5        NaN     NONE    Average        1300
# 1026    315000.0         4     1.5        NaN     NONE       Good        1300
# 1717    700000.0         4     1.0         NO     GOOD       Good        1300
# 2533    595000.0         4     1.5         NO     NONE  Very Good        1300
# 3356    400000.0         4     1.0         NO     NONE       Good        1300
# 3514    328950.0         4     1.0         NO     NONE  Very Good        1300
# 4148    378950.0         4     1.0         NO     NONE  Very Good        1300
# 4799    650000.0         4     1.0         NO     NONE    Average        1300
# 7221    506000.0         4     1.0         NO     NONE       Good        1300
# 7385    584999.0         4     1.0         NO     NONE       Good        1300
# 7624    380000.0         4     1.0         NO  AVERAGE       Good        1300
# ...

# %%
#The code below has been used to get the mean of the prices for 4 bedrooms houses
round(non_bed4['Price'].mean(),2)
# Out:
# 471542.82

# %%
data1['Sqft_basement'].value_counts()
# Out:
# Sqft_basement
# 0.0       12826
# ?           454
# 600.0       217
# 500.0       209
# 700.0       208
#           ...
# 1920.0        1
# 3480.0        1
# 2730.0        1
# 2720.0        1
# 248.0         1
# Name: count, Length: 304, dtype: int64

# %% [markdown]
# The analysis above was done based on the squarefoot above as the common factor to determine whether the value of the renovated houses would have an effect on the price compared to the non_renovated houses. Now the codes below are based on other factors to determine the trend if the will be the same as for the above codes.

# %%
#Finding the mode of the floor in the variable renovated 
renovated['Floors'].mode()
# Out:
# 0    1.0
# Name: Floors, dtype: float64

# %%
floor = renovate[(renovate['Floors'] == 1.0)]
floor
# Out:
#            Price  Bedrooms  Floors Waterfront  View Condition  Sqft_above  \
# 95      905000.0         4     1.0         NO  NONE   Average        2390
# 216    1510000.0         5     1.0        NaN  GOOD   Average        1870
# 274     331000.0         3     1.0         NO  NONE   Average         580
# 324     232000.0         2     1.0        NaN  NONE   Average         960
# 325     240500.0         2     1.0         NO  NONE   Average         960
# ...          ...       ...     ...        ...   ...       ...         ...
# 19472   234000.0         4     1.0        NaN  NONE   Average        1390
# 19577   257000.0         3     1.0         NO  NONE   Average        1397
# 19602   451000.0         2     1.0         NO  NONE   Average         900
# 20428   500012.0         4     1.0         NO  NONE   Average        1230
# 20946   110000.0         2     1.0         NO  NONE   Average         828
#
#        Yr_built  Yr_renovated  Yr_dif
# 95         1946        1991.0    45.0
# ...

# %%
#The variable f_bed1 was used to display the info for all houses that has one bedroom with the mode of the floor 
f_bed1 = floor[(floor['Bedrooms'] == 1)]
f_bed1
# Out:
#           Price  Bedrooms  Floors Waterfront       View  Condition  \
# 1732   252000.0         1     1.0        NaN  EXCELLENT       Poor
# 2029   152900.0         1     1.0         NO       NONE  Very Good
# 2154   410000.0         1     1.0         NO       NONE    Average
# 3300   334000.0         1     1.0         NO       NONE    Average
# 4142   330600.0         1     1.0         NO       NONE    Average
# 6556   269000.0         1     1.0         NO       NONE    Average
# 7368   250000.0         1     1.0         NO       NONE    Average
# 12811  291970.0         1     1.0         NO       NONE    Average
# 13830  550000.0         1     1.0         NO       NONE    Average
#
#        Sqft_above  Yr_built  Yr_renovated  Yr_dif
# 1732          680      1910        1992.0    82.0
# 2029          900      1915        1950.0    35.0
# 2154         1010      1911        1948.0    37.0
# 3300          670      1942        2011.0    69.0
# ...

# %%
#Show the mean price of the varible f_bed1
round(f_bed1['Price'].mean(),2)
# Out:
# 315607.78

# %%
#Show the non_renovated houses that has one floors 
floors = non_renovate[(non_renovate['Floors'] == 1.0)]
floors
# Out:
#            Price  Bedrooms  Floors Waterfront     View  Condition  Sqft_above  \
# 0       221900.0         3     1.0        NaN     NONE    Average        1180
# 3       604000.0         4     1.0         NO     NONE  Very Good        1050
# 4       510000.0         3     1.0         NO     NONE    Average        1680
# 5      1230000.0         4     1.0         NO     NONE    Average        3890
# 7       291850.0         3     1.0         NO      NaN    Average        1060
# ...          ...       ...     ...        ...      ...        ...         ...
# 21454   249000.0         3     1.0         NO  AVERAGE    Average        1030
# 21474   529000.0         3     1.0         NO     NONE    Average        2340
# 21488   810000.0         2     1.0         NO     NONE    Average        2700
# 21554   330000.0         3     1.0         NO     NONE    Average         840
# 21586   224000.0         3     1.0        NaN     NONE    Average        1500
#
# ...

# %%
#Shows the mode of the waterfront from the variable renovated 
renovated['Waterfront'].mode()
# Out:
# 0    NO
# Name: Waterfront, dtype: object

# %%
#Show all the houses that has waterfronts 
water = renovated[(renovated['Waterfront'] == 'YES')]
water
# Out:
#            Price  Bedrooms  Floors Waterfront       View  Condition  \
# 49     1350000.0         3     1.0        YES    AVERAGE  Very Good
# 230     655000.0         2     2.0        YES  EXCELLENT    Average
# 246    2400000.0         4     1.0        YES  EXCELLENT    Average
# 264     369900.0         1     1.0        YES  EXCELLENT  Very Good
# 300    3080000.0         4     1.0        YES  EXCELLENT    Average
# ...          ...       ...     ...        ...        ...        ...
# 19968  1900000.0         3     3.0        YES  EXCELLENT    Average
# 20309  3000000.0         3     2.0        YES  EXCELLENT    Average
# 20751  2300000.0         4     2.5        YES  EXCELLENT    Average
# 21185  2230000.0         3     2.0        YES  EXCELLENT    Average
# 21560  3570000.0         5     2.0        YES  EXCELLENT    Average
#
#        Sqft_above  Yr_built  Yr_renovated  Yr_dif
# 49           2165      1953           0.0 -1953.0
# ...

# %%
#Shows all the houses that doesn't have waterfronts 
no_water = renovated[(renovated['Waterfront'] == 'NO')]
no_water
# Out:
#            Price  Bedrooms  Floors Waterfront  View  Condition  Sqft_above  \
# 1       538000.0         3     2.0         NO  NONE    Average        2170
# 2       180000.0         2     1.0         NO  NONE    Average         770
# 3       604000.0         4     1.0         NO  NONE  Very Good        1050
# 4       510000.0         3     1.0         NO  NONE    Average        1680
# 5      1230000.0         4     1.0         NO  NONE    Average        3890
# ...          ...       ...     ...        ...   ...        ...         ...
# 21591   475000.0         3     2.0         NO  NONE    Average        1180
# 21592   360000.0         3     3.0         NO  NONE    Average        1530
# 21593   400000.0         4     2.0         NO  NONE    Average        2310
# 21594   402101.0         2     2.0         NO  NONE    Average        1020
# 21596   325000.0         2     2.0         NO  NONE    Average        1020
#
#        Yr_built  Yr_renovated  Yr_dif
# ...

# %%
#Show all houses that have waterfronts and have been renovated 
ren_water = water[(water['Yr_renovated'] > 1600)]
ren_water
# Out:
#            Price  Bedrooms  Floors Waterfront       View  Condition  \
# 230     655000.0         2     2.0        YES  EXCELLENT    Average
# 1259    995000.0         3     2.0        YES       GOOD    Average
# 1947    480000.0         2     1.0        YES  EXCELLENT       Good
# 2862   3600000.0         3     2.0        YES  EXCELLENT    Average
# 3249   1000000.0         5     2.0        YES  EXCELLENT  Very Good
# 3910   7060000.0         5     2.0        YES    AVERAGE    Average
# 3930   1380000.0         3     1.0        YES  EXCELLENT    Average
# 4365   1150000.0         3     2.0        YES  EXCELLENT    Average
# 4758   1850000.0         5     2.0        YES  EXCELLENT    Average
# 5755   1100000.0         4     2.0        YES  EXCELLENT    Average
# 6765   2700000.0         5     2.0        YES  EXCELLENT    Average
# 8085   4670000.0         5     1.0        YES  EXCELLENT    Average
# 8775   1800000.0         3     2.0        YES  EXCELLENT       Good
# ...

# %%
#Shows all the houses that have waterfronts but haven't been renovated 
non_ren_water = water[(water['Yr_renovated'] < 1600)]
non_ren_water
# Out:
#            Price  Bedrooms  Floors Waterfront       View  Condition  \
# 49     1350000.0         3     1.0        YES    AVERAGE  Very Good
# 246    2400000.0         4     1.0        YES  EXCELLENT    Average
# 264     369900.0         1     1.0        YES  EXCELLENT  Very Good
# 300    3080000.0         4     1.0        YES  EXCELLENT    Average
# 457     705000.0         3     2.0        YES       GOOD       Good
# ...          ...       ...     ...        ...        ...        ...
# 19968  1900000.0         3     3.0        YES  EXCELLENT    Average
# 20309  3000000.0         3     2.0        YES  EXCELLENT    Average
# 20751  2300000.0         4     2.5        YES  EXCELLENT    Average
# 21185  2230000.0         3     2.0        YES  EXCELLENT    Average
# 21560  3570000.0         5     2.0        YES  EXCELLENT    Average
#
#        Sqft_above  Yr_built  Yr_renovated  Yr_dif
# 49           2165      1953           0.0 -1953.0
# ...

# %%
#Shows the mean of the year differences(Yr_dif) 
round(renovate['Yr_dif'].mean(),2)
# Out:
# 56.47

# %%
#The graph below has been used to determine the mode of the highest condition for most houses in the northwestren county
plt.title('No. of houses per condition')
sns.histplot(data1["Condition"], bins=5, color='#C3B091', kde=True)
# Out:
# <Axes: title={'center': 'No. of houses per condition'}, xlabel='Condition', ylabel='Count'>

# %%
#The graph shows the average mean of how long a built house has stayed before renovation 
plt.title('No. of houses per peroid before renovation')
sns.histplot(renovate["Yr_dif"], bins=5, color='#C3B091', kde=True)
# Out:
# <Axes: title={'center': 'No. of houses per peroid before renovation'}, xlabel='Yr_dif', ylabel='Count'>

# %%
#From this graph will are able to tell when and how long a non_renovated house has stayed and was built
plt.title('No. of houses per when it was built')
sns.histplot(non_renovate["Yr_dif"], bins=5, color='#C3B091', kde=True)
# Out:
# <Axes: title={'center': 'No. of houses per when it was built'}, xlabel='Yr_dif', ylabel='Count'>

# %%
#From this graph we are able to tell when were majority of the houses in the county was built 
plt.title('No. of houses per year built')
sns.histplot(data1["Yr_built"], bins=5, color='#C3B091', kde=True)
# Out:
# <Axes: title={'center': 'No. of houses per year built'}, xlabel='Yr_built', ylabel='Count'>

# %%
#The graph below and in the next cell has been used to show the count and the percentages of houses that have a waterfront
front_count = data1["Waterfront"].value_counts()
front_count.plot(kind="pie", autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.barplot(front_count)
# Out:
# <Axes: xlabel='Waterfront', ylabel='count'>

# %% [markdown]
# The following graphs are used to show the trends of the value of prices in both renovated houses and non_renovated houses.From the graphs we are able to come up with a trend of renovated houses depreciating in value under the relation of sqft_above. Now the graphs below are based on sqft_above and other relations to determine whether the trend found is the same or different.

# %%
#For this graph and the next show the info for non_renovated houses
plt.title('Price vs Bedrooms')
cost_gr = non_renovate.groupby(["Bedrooms"])["Price"].sum()
cost_gr.plot(kind="bar");

# %%
sns.barplot(cost_gr)
plt.title('Price in millions vs No. of Bedrooms')
# Out:
# Text(0.5, 1.0, 'Price in millions vs No. of Bedrooms')

# %%
#Show the value of houses per the number of bedrooms against the price
plt.title('Price vs Bedrooms')
sns.scatterplot(x = "Price", y = "Bedrooms", data=renovate)
# Out:
# <Axes: title={'center': 'Price vs Bedrooms'}, xlabel='Price', ylabel='Bedrooms'>

# %%
#For this graph and the next show the info for renovated houses 
plt.title('Price vs Bedrooms')
cost1_gr = renovate.groupby(["Bedrooms"])["Price"].sum()
cost1_gr.plot(kind="bar");

# %%
sns.barplot(cost1_gr)
plt.title('Price in millions vs No. of Bedrooms')
# Out:
# Text(0.5, 1.0, 'Price in millions vs No. of Bedrooms')

# %%
#Shows the all the possible graph for renovated houses 
sns.pairplot(renovate)

# %%
#Shows the all the possible graph for non_renovated houses 
sns.pairplot(non_renovate)

# %%
#From this graph and the next shows the attempt to determine the trend in the renovated houses under the relation floor
plt.title('Price vs Bedrooms')
flor1_gr = floor.groupby(["Bedrooms"])["Price"].sum()
flor1_gr.plot(kind="bar");

# %%
sns.barplot(flor1_gr)
plt.title('Price vs Bedrooms')
# Out:
# Text(0.5, 1.0, 'Price vs Bedrooms')

# %%
#From this graph and the next shows the attempt to determine the trend in the non_renovated houses under the relation floor
plt.title('Price vs Bedrooms')
flor_gr = floors.groupby(["Bedrooms"])["Price"].sum()
flor_gr.plot(kind="bar");

# %%
sns.barplot(flor_gr)
plt.title('Price vs Bedrooms')
# Out:
# Text(0.5, 1.0, 'Price vs Bedrooms')

# %%
#From this graph and the next shows the trend in the renovated houses under the relation floor in different chart 
plt.title('Price vs Floors')
flor_gr = renovate.groupby(["Floors"])["Price"].sum()
flor_gr.plot(kind="bar");

# %%
sns.barplot(flor_gr)
plt.title('Price in millions vs No. of Floors')
# Out:
# Text(0.5, 1.0, 'Price in millions vs No. of Floors')

# %%
#From this graph and the next shows the trend in the non_renovated houses under the relation floor in different chart
plt.title('Price vs Floors')
flor_gr = non_renovate.groupby(["Floors"])["Price"].sum()
flor_gr.plot(kind="bar");

# %%
sns.barplot(flor_gr)
plt.title('Price in millions vs No. of Floors')
# Out:
# Text(0.5, 1.0, 'Price in millions vs No. of Floors')

# %%
#This graph was used to determine whether houses that have a waterfont which condition is the highest
front_count = renovate['Waterfront'].value_counts()
cond_count = renovate['Condition'].value_counts()

crosst = pd.crosstab(renovate['Waterfront'], renovate['Condition'])

crosst.plot(kind='bar')
# Out:
# <Axes: xlabel='Waterfront'>

# %%
#This graph was used to determine whether houses that doesn't have a waterfont which condition is the highest
front1_count = non_renovate['Waterfront'].value_counts()
cond1_count = non_renovate['Condition'].value_counts()

crosst = pd.crosstab(non_renovate['Waterfront'], non_renovate['Condition'])

crosst.plot(kind='bar')
# Out:
# <Axes: xlabel='Waterfront'>

# %%
#Same camparison for condition is done but now with bedrooms for this graph and the next 
plt.title('Bedrooms vs Condition')
flor_gr = renovate.groupby(["Condition"])["Bedrooms"].sum()
flor_gr.plot(kind="pie", autopct='%1.2f%%');

# %%
sns.barplot(flor_gr)
plt.title('No. of Bedrooms vs Condition')
# Out:
# Text(0.5, 1.0, 'No. of Bedrooms vs Condition')

# %%
#Show houses that have a waterfront from the variable renovate
plt.title('Price vs Bedrooms')
sns.scatterplot(data=renovate, x ="Bedrooms", y = "Price", hue="Waterfront");

# %%
#Show houses that have a waterfront from the variable non_renovate
plt.title('Price vs Bedrooms')
sns.scatterplot(data=non_renovate, x ="Bedrooms", y = "Price", hue="Waterfront");

# %%
#Show the bedrooms with their price together with their condition for each bedroom for renovated houses
plt.title('Price vs Bedrooms')
sns.scatterplot(data=renovate, x ="Bedrooms", y = "Price", hue="Condition");

# %%
#Show the bedrooms with their price together with their condition for each bedroom for non_renovated houses
plt.title('Price vs Bedrooms')
sns.scatterplot(data=non_renovate, x ="Bedrooms", y = "Price", hue="Condition");

# %%
#Shows the graph for condition and bedrooms in another form in this chart and the next for renovated houses
plt.title('Bedrooms vs Condition')
flor_gr = above.groupby(["Condition"])["Bedrooms"].sum()
flor_gr.plot(kind="bar");

# %%
sns.barplot(flor_gr)
plt.title('Bedrooms vs Condition')
# Out:
# Text(0.5, 1.0, 'Bedrooms vs Condition')

# %%
#Shows the graph for condition and bedrooms in another form in this chart and the next for non_renovated houses
flor_gr = non_beds.groupby(["Condition"])["Bedrooms"].sum()
flor_gr.plot(kind="bar");

# %%
sns.barplot(flor_gr)
plt.title('Bedrooms vs Condition')
# Out:
# Text(0.5, 1.0, 'Bedrooms vs Condition')

# %%
#Shows the graph for condition and bedrooms in another form in this chart and the next for renovated houses
plt.figure(figsize=(10,5))
sns.boxplot(x = 'Condition', y = 'Bedrooms', data = renovate)
plt.title('Bedrooms vs Condition')
plt.show()

# %%
#Shows the graph for condition and bedrooms in another form in this chart and the next for non_renovated houses
plt.figure(figsize=(10,5))
sns.boxplot(x = 'Condition', y = 'Bedrooms', data = non_renovate)
plt.title('Bedrooms vs Condition')
plt.show()

# %%
#From this graph and the next is used to determine if the age of the houses affects the cost of the houses in renovated houses 
flor_gr = renovate.groupby(["Yr_dif"])["Price"].sum()
flor_gr.plot(kind="bar");

# %%
sns.barplot(flor_gr)
plt.title('Price per Yr_dif')
# Out:
# Text(0.5, 1.0, 'Price per Yr_dif')

# %%
#From this graph and the next is used to determine if the age of the houses affects the cost of the houses in non_renovated houses 
flor_gr = non_renovate.groupby(["Yr_dif"])["Price"].sum()
flor_gr.plot(kind="bar");

# %%
sns.barplot(flor_gr)
plt.title('Price per Yr_dif')
# Out:
# Text(0.5, 1.0, 'Price per Yr_dif')

# %%
#data1.to_csv("kc_housing_analysis6.csv")
